# %%
import ruamel.yaml as yaml
import os
import sys
import pandas as pd
import numpy as np


NO_CONFIG_ERR_MSG = """No config file found. Root directory is determined by presence of "config.yaml" file."""

original_wd = os.getcwd()

# Number of times to move back in directory
num_retries = 10
for x in range(0, num_retries):
    # try to load config file
    try:
        with open("config.yaml", 'r') as stream:
            cfg = yaml.safe_load(stream)
    # If not found move back one directory level
    except FileNotFoundError:
        os.chdir('../')
        # If reached the max number of directory levels change to original wd and print error msg
        if x+1 == num_retries:
            os.chdir(original_wd)
            print(NO_CONFIG_ERR_MSG)

# Add directory to PATH
path = os.getcwd()

if path not in sys.path:
    sys.path.append(path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5925e7a7889d> in <module>()
# ----> 1 import ruamel.yaml as yaml
#       2 import os
#       3 import sys
#       4 import pandas as pd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'ruamel'

# %% [markdown]
# ## Load Data

# %%
RPM_df = pd.read_csv('data/interim/player_RPM_stats.csv')
box_score_df = pd.read_csv('data/raw/Box_Scores.csv')

# %% [markdown]
# ## Joining RPM to players
#
# Need to join on composite key made up of Player Name + Season

# %% [markdown]
# season_id appears to be calendar year the season started in
#
# Based off of the latest season being 2017 and not 2018

# %%
box_score_df['season_id'].unique()
# Out:
# array([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017], dtype=int64)

# %%
RPM_df.head()
# Out:
#    DRPM  GP   MPG  ORPM   RPM  Season_End_Year  Season_Start_Year   WINS  \
# 0  1.95  62  35.0  6.03  7.98             2014               2013  14.47
# 1  0.15  81  38.5  6.27  6.42             2014               2013  17.63
# 2 -0.38  78  36.5  6.62  6.24             2014               2013  15.48
# 3  0.35  68  22.8  5.07  5.42             2014               2013   7.68
# 4  3.23  69  36.2  1.89  5.12             2014               2013  11.64
#
#                names  name_length_post_split
# 0         Chris Paul                       2
# 1       Kevin Durant                       2
# 2      Stephen Curry                       2
# 3      Manu Ginobili                       2
# 4  LaMarcus Aldridge                       2

# %%
# most number of whitespaces 
RPM_df['names'].str.split(' ').apply(len).max()
# Out:
# 4

# %%
# Who has more than one space?

RPM_df['name_length_post_split'] = RPM_df['names'].str.split(' ').apply(len)
RPM_df.query("name_length_post_split > 2").names.value_counts().head()

# Mostly Jrs and some multiple names
# Out:
# Tim Hardaway Jr.        5
# Otto Porter Jr.         5
# Luc Mbah a Moute        5
# James Michael McAdoo    4
# Glenn Robinson III      4
# Name: names, dtype: int64

# %% [markdown]
# What's the RPM of these players?

# %%
RPM_df.query("name_length_post_split > 2").RPM.describe()
# Out:
# count    51.000000
# mean     -1.338627
# std       2.072766
# min      -6.390000
# 25%      -2.375000
# 50%      -1.620000
# 75%      -0.440000
# max       4.960000
# Name: RPM, dtype: float64

# %%
first_name_to_search = 'Tim'
box_score_df[box_score_df.First_Name.str.contains(first_name_to_search)].head()
# Out:
#       Game_id  Person_id     Team_id First_Name Last_Name  minutes  \
# 28   20300002       1495  1610612759    Timothy    Duncan       40
# 173  20300009       1501  1610612749    Timothy    Thomas       30
# 210  20300011       1495  1610612759    Timothy    Duncan       34
# 408  20300021       1501  1610612749    Timothy    Thomas       32
# 636  20300032       1501  1610612749    Timothy    Thomas       29
#
#      Field_Goals  Field_Goals_Attempted  Field_Goal_Percentage  \
# 28             8                     13                  0.615
# 173            5                     17                  0.294
# 210            7                     22                  0.318
# 408            7                     12                  0.583
# 636            6                     15                  0.400
#
#      Three_Pointers       ...        Fast_Break_Points  Triple_Doubles  \
# 28                0       ...                      0.0             0.0
# 173               0       ...                      0.0             0.0
# 210               0       ...                      2.0             0.0
# 408               2       ...                      5.0             0.0
# 636               2       ...                      2.0             0.0
#
#      Double_Doubles  actual_minutes  actual_seconds  Plus_Minus  \
# 28              1.0              40               0          -4
# 173             0.0              30               0         -19
# 210             1.0              34               0         -19
# 408             0.0              32               0          17
# 636             0.0              29               0          13
#
#      Blocks_Against  PTS_OFF_TO  Second_Chance_PTS  Total_Rebounds
# 28              1.0           2                  6            12.0
# 173             2.0           4                  4             3.0
# 210             2.0           2                  6            21.0
# 408             0.0           2                  7             6.0
# 636             2.0           4                  0             4.0
#
# [5 rows x 41 columns]

# %% [markdown]
# #### For now, will join to get RPM on a season/team/player level and fix this later if necessary

# %%
potential_keys = [
    'First_Name',
    'Last_Name',
    'season_id',
]

# %% [markdown]
# #### Steps:
#
# 1) RPM: Seperate names into first and last (start by splitting on a space)
#
# 2) Match season_id to either the calendar year the season ended or began. Map to RPM data
#
# 3) Join on First, Last, Season

# %%
game_mapping_df = pd.read_csv('data/raw/Game_Mapping.csv')
game_mapping_df.head()
game_mapping_df['Calendar_Year'] = game_mapping_df.Date_EST.str.split('/').str.get(-1)
calendar_year_to_df_map = game_mapping_df.groupby(by=['Calendar_Year', 'Season']).size().to_frame('count').reset_index()

# %%
team_tricodes_df = pd.read_csv('data/raw/Team_Tricodes.csv')
team_tricodes_df.head()
# Out:
#   Abbr  NBA_Flag          Team_Name
# 0  ATL         1      Atlanta Hawks
# 1  BRK         1      Brooklyn Nets
# 2  BOS         1     Boston Celtics
# 3  CHA         1  Charlotte Hornets
# 4  CHI         1      Chicago Bulls

# %%
team_mapping = pd.read_csv('data/raw/Team_Mapping.csv')
team_mapping.head(20)
# Out:
#        Team_id  Season_id  Arena_id Conference_id Division_id Short_Name  \
# 0   1610612737      22003     135.0          East     Central    Atlanta
# 1   1610612737      22004     135.0          East   Southeast    Atlanta
# 2   1610612737      22005     135.0          East   Southeast    Atlanta
# 3   1610612737      22006     135.0          East   Southeast    Atlanta
# 4   1610612737      22007     135.0          East   Southeast    Atlanta
# 5   1610612737      22008     135.0          East   Southeast    Atlanta
# 6   1610612737      22009     135.0          East   Southeast    Atlanta
# 7   1610612737      22010     135.0          East   Southeast    Atlanta
# 8   1610612737      22011     135.0          East   Southeast    Atlanta
# 9   1610612737      22012     135.0          East   Southeast    Atlanta
# 10  1610612737      22013     135.0          East   Southeast    Atlanta
# 11  1610612737      22014     135.0          East   Southeast    Atlanta
# 12  1610612737      22015     135.0          East   Southeast    Atlanta
# 13  1610612737      22016     135.0          East   Southeast    Atlanta
# 14  1610612737      22017     135.0          East   Southeast    Atlanta
# 15  1610612737      42007     135.0          East   Southeast    Atlanta
# 16  1610612737      42008     135.0          East   Southeast    Atlanta
# 17  1610612737      42009     135.0          East   Southeast    Atlanta
# 18  1610612737      42010     135.0          East   Southeast    Atlanta
# 19  1610612737      42011     135.0          East   Southeast    Atlanta
#
#    Nickname     City State Country
# 0     Hawks  Atlanta    GA     USA
# 1     Hawks  Atlanta    GA     USA
# 2     Hawks  Atlanta    GA     USA
# 3     Hawks  Atlanta    GA     USA
# 4     Hawks  Atlanta    GA     USA
# 5     Hawks  Atlanta    GA     USA
# 6     Hawks  Atlanta    GA     USA
# 7     Hawks  Atlanta    GA     USA
# 8     Hawks  Atlanta    GA     USA
# 9     Hawks  Atlanta    GA     USA
# 10    Hawks  Atlanta    GA     USA
# 11    Hawks  Atlanta    GA     USA
# 12    Hawks  Atlanta    GA     USA
# 13    Hawks  Atlanta    GA     USA
# 14    Hawks  Atlanta    GA     USA
# 15    Hawks  Atlanta    GA     USA
# 16    Hawks  Atlanta    GA     USA
# 17    Hawks  Atlanta    GA     USA
# 18    Hawks  Atlanta    GA     USA
# 19    Hawks  Atlanta    GA     USA

# %%
calendar_year_to_df_map
# Out:
#    Calendar_Year  Season  count
# 0           2003   22003    450
# 1           2004   22003    739
# 2           2004   22004    426
# 3           2004   42003    105
# 4           2005   22004    804
# 5           2005   22005    434
# 6           2005   42004    105
# 7           2006   22005    796
# 8           2006   22006    456
# 9           2006   42005    107
# 10          2007   22006    774
# 11          2007   22007    456
# 12          2007   42006    107
# 13          2008   22007    774
# 14          2008   22008    472
# 15          2008   42007    108
# 16          2009   22008    758
# 17          2009   22009    473
# 18          2009   42008    105
# 19          2010   22009    757
# 20          2010   22010    482
# 21          2010   42009    105
# 22          2011   22010    748
# 23          2011   22011     56
# 24          2011   42010    105
# 25          2012   22011    934
# 26          2012   22012    456
# 27          2012   42011    105
# 28          2013   22012    774
# 29          2013   22013    466
# 30          2013   42012    105
# 31          2014   22013    764
# 32          2014   22014    481
# 33          2014   42013    105
# 34          2015   22014    749
# 35          2015   22015    489
# 36          2015   42014    105
# 37          2016   22015    741
# 38          2016   22016    506
# 39          2016   42015    105
# 40          2017   22016    724
# 41          2017   22017    544
# 42          2017   42016    105
# 43          2018   22017    686
# 44          2018   42017    105

# %%
# Only use season codes that start with 2
season_codes = [season_code for season_code in calendar_year_to_df_map.Season.unique() if str(season_code).startswith('2')]
season_code_starting_year = [int(str(season_code)[1:]) for season_code in season_codes]
season_code_ending_year = [season_code+1 for season_code in season_code_starting_year]

# %%
season_id_records = {
    'season_id':season_codes,
    'Season_Start_Year':season_code_starting_year,
    'Season_End_Year':season_code_ending_year,
    
}

# %%
season_id_map = pd.DataFrame.from_dict(season_id_records)
season_id_map.head()
# Out:
#    Season_End_Year  Season_Start_Year  season_id
# 0             2004               2003      22003
# 1             2005               2004      22004
# 2             2006               2005      22005
# 3             2007               2006      22006
# 4             2008               2007      22007

# %% [markdown]
# #### Merge to RPM data and check for nulls

# %%
RPM_df = pd.merge(RPM_df,
        season_id_map,
        on=['Season_Start_Year', 'Season_End_Year'],
                 how='left')

RPM_df['season_id'].isnull().sum()
# Out:
# 0

# %%
RPM_df.head()
# Out:
#    DRPM  GP   MPG  ORPM   RPM  Season_End_Year  Season_Start_Year   WINS  \
# 0  1.95  62  35.0  6.03  7.98             2014               2013  14.47
# 1  0.15  81  38.5  6.27  6.42             2014               2013  17.63
# 2 -0.38  78  36.5  6.62  6.24             2014               2013  15.48
# 3  0.35  68  22.8  5.07  5.42             2014               2013   7.68
# 4  3.23  69  36.2  1.89  5.12             2014               2013  11.64
#
#                names  name_length_post_split  season_id
# 0         Chris Paul                       2      22013
# 1       Kevin Durant                       2      22013
# 2      Stephen Curry                       2      22013
# 3      Manu Ginobili                       2      22013
# 4  LaMarcus Aldridge                       2      22013

# %% [markdown]
# #### Split Names First and Last

# %%
RPM_df['First_Name'] = RPM_df['names'].str.split(' ').str.get(0)
RPM_df['Last_Name'] = RPM_df['names'].str.split(' ').str.get(-1)

# %% [markdown]
# ## Merge onto Box score

# %%
RPM_df[potential_keys].dtypes
# Out:
# First_Name    object
# Last_Name     object
# season_id      int64
# dtype: object

# %%
box_score_df[potential_keys].dtypes
# Out:
# First_Name    object
# Last_Name     object
# season_id      int64
# dtype: object

# %% [markdown]
# Max should be number of seasons since 2013 (when RPM was introduced)

# %%
RPM_df[potential_keys].groupby(by=['First_Name', 'Last_Name']).count().sort_values(by='season_id', ascending=False).head()
# Out:
#                       season_id
# First_Name Last_Name
# Manu       Ginobili           5
# Russell    Westbrook          5
# Rudy       Gobert             5
#            Gay                5
# DeAndre    Jordan             5

# %%
box_score_df[potential_keys]
# Out:
#        First_Name   Last_Name  season_id
# 0           Eddie       Jones       2003
# 1           Aaron       McKie       2003
# 2           Brian       Grant       2003
# 3            Eric        Snow       2003
# 4         Vernell       Coles       2003
# 5         Derrick     Coleman       2003
# 6           Allen     Iverson       2003
# 7          Samaki      Walker       2003
# 8            John     Wallace       2003
# 9            Amal   McCaskill       2003
# 10           Marc     Jackson       2003
# 11          Rafer      Alston       2003
# 12          Lamar        Odom       2003
# 13        Kenneth      Thomas       2003
# 14          Malik       Allen       2003
# 15         Samuel   Dalembert       2003
# 16          Loren       Woods       2003
# 17           John     Salmons       2003
# 18         Dwyane        Wade       2003
# 19         Willie       Green       2003
# 20           Kyle      Korver       2003
# 21         Udonis      Haslem       2003
# 22         Robert       Horry       2003
# 23         Thomas   Gugliotta       2003
# 24       Anfernee    Hardaway       2003
# 25        Stephon     Marbury       2003
# 26          Malik        Rose       2003
# 27          Bruce       Bowen       2003
# 28        Timothy      Duncan       2003
# 29         Ronald      Mercer       2003
# ...           ...         ...        ...
# 400571     Rodney        Hood       2017
# 400572      Kevon      Looney       2017
# 400573      Larry   Nance Jr.       2017
# 400574    Patrick       McCaw       2017
# 400575     Jordan        Bell       2017
# 400576     LeBron       James       2017
# 400577      David        West       2017
# 400578       Zaza    Pachulia       2017
# 400579       Kyle      Korver       2017
# 400580      Shaun  Livingston       2017
# 400581      Andre    Iguodala       2017
# 400582         JR       Smith       2017
# 400583       Jose    Calderon       2017
# 400584      Kevin      Durant       2017
# 400585       Jeff       Green       2017
# 400586       Nick       Young       2017
# 400587      Kevin        Love       2017
# 400588     JaVale       McGee       2017
# 400589     George        Hill       2017
# 400590    Stephen       Curry       2017
# 400591    Tristan    Thompson       2017
# 400592       Klay    Thompson       2017
# 400593   Draymond       Green       2017
# 400594     Rodney        Hood       2017
# 400595      Kevon      Looney       2017
# 400596      Larry   Nance Jr.       2017
# 400597       Cedi       Osman       2017
# 400598    Patrick       McCaw       2017
# 400599       Ante       Zizic       2017
# 400600     Jordan        Bell       2017
#
# [400601 rows x 3 columns]

# %%
test_merge = pd.merge(RPM_df, box_score_df,
                     on=['season_id', 'First_Name', 'Last_Name'],
                     )

test_merge.head()
# Out:
# Empty DataFrame
# Columns: [DRPM, GP, MPG, ORPM, RPM, Season_End_Year, Season_Start_Year, WINS, names, name_length_post_split, season_id_x, season_id_y, season_id_x, season_id_y, season_id, First_Name, Last_Name, Game_id, Person_id, Team_id, minutes, Field_Goals, Field_Goals_Attempted, Field_Goal_Percentage, Three_Pointers, Three_Pointers_Attempted, Three_Point_Percentage, Free_Throws, Free_Throws_Attempted, Free_Throw_Percentage, Offensive_Rebounds, Defensive_Rebounds, Assists, Personal_Fouls, Steals, Turnovers, Blocked_Shots, Points, location, outcome, vs_team_id, Technical_Fouls, Flagrant_Fouls, Ejections, Points_In_Paint, Fast_Break_Points, Triple_Doubles, Double_Doubles, actual_minutes, actual_seconds, Plus_Minus, Blocks_Against, PTS_OFF_TO, Second_Chance_PTS, Total_Rebounds]
# Index: []
#
# [0 rows x 55 columns]
